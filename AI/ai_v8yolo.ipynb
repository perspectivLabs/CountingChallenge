# %%
import torch

# %%
import cv2
import numpy as np
import os

# %%
from ultralytics import YOLO

def load_model():
    # Load yolov8 model
    # model = YOLO("yolov8s.pt")
    # model = YOLO("yolov8l.pt")
    model = YOLO("yolov8s.pt")

    return model

# %%
def process_image(model, image_path, output_dir):
    # Read the image
    image = cv2.imread(image_path)
    results = model(image)
    
    # # Draw bounding boxes and labels
    # annotated_image = results.render()[0]
    # num_items = len(results.pred[0])
    # num_masks = len(results.pred[0])

    # Extract information from the results
    num_items = len(results)
    num_masks = num_items  # Since each detection corresponds to a mask
    
    # Draw bounding boxes
    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
            confidence = box.conf[0]
            class_id = box.cls[0]
            label = f"{model.names[int(class_id)]} {confidence:.2f}"
            cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    # Add text annotation
    cv2.putText(image, f"Items Count: {num_items}", (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2, cv2.LINE_AA)
    cv2.putText(image, f"Masks Count: {num_masks}", (10, 70), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 255), 2, cv2.LINE_AA)
    
    # Save the result in the output directory
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
        
    filename = os.path.basename(image_path)
    output_path = os.path.join(output_dir, filename)
    cv2.imwrite(output_path, image)
    
    return num_items, num_masks

# %%
def process_directory(model, input_dir, output_dir):
    for filename in os.listdir(input_dir):
        if filename.endswith(".jpg"):
            image_path = os.path.join(input_dir, filename)
            items_count, masks_count = process_image(model, image_path, output_dir)
            print(f"Processed {filename}: {items_count} items detected, {masks_count} masks drawn.")

# %%
if __name__ == "__main__":
    
    model = load_model()
    
    screws_and_bolts_dir = 'F:/Ankit_CountingChallenge/Original_datasets/ScrewAndBolt_20240713'
    screws_and_bolts_output_dir = 'F:/Ankit_CountingChallenge/Original_datasets/AI_v8_output_ScrewAndBolt'
    
    screws_dir = 'F:/Ankit_CountingChallenge/Original_datasets/Screws_2024_07_15'
    screws_output_dir = 'F:/Ankit_CountingChallenge/Original_datasets/AI_v8_output_Screws'
    
    print("Processing Screws_and_bolts dataset...")
    process_directory(model, screws_and_bolts_dir, screws_and_bolts_output_dir)
    
    print("Processing screws dataset...")
    process_directory(model, screws_dir, screws_output_dir)
# Out:
# Processing Screws_and_bolts dataset...
#
# 0: 640x480 15 kites, 411.0ms
# Speed: 8.0ms preprocess, 411.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_192951.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x512 11 kites, 339.0ms
# Speed: 6.0ms preprocess, 339.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
# Processed 20240713_193135.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x512 7 airplanes, 323.0ms
# Speed: 4.0ms preprocess, 323.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
# Processed 20240713_193650.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x512 7 airplanes, 1 kite, 282.0ms
# Speed: 5.0ms preprocess, 282.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 512)
# Processed 20240713_193659.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 4 birds, 264.0ms
# Speed: 7.0ms preprocess, 264.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_193831.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 13 birds, 255.0ms
# Speed: 4.0ms preprocess, 255.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_193839.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 10 birds, 262.0ms
# Speed: 4.0ms preprocess, 262.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_193907.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x512 2 airplanes, 7 birds, 285.5ms
# Speed: 4.0ms preprocess, 285.5ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 512)
# Processed 20240713_194200.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 2 airplanes, 6 birds, 266.0ms
# Speed: 5.0ms preprocess, 266.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_194206.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 1 airplane, 21 birds, 263.0ms
# Speed: 5.0ms preprocess, 263.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_194215.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 13 birds, 1 kite, 247.0ms
# Speed: 5.0ms preprocess, 247.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_194232.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 14 birds, 334.0ms
# Speed: 6.0ms preprocess, 334.0ms inference, 5.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_194256.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 4 birds, 6 kites, 263.0ms
# Speed: 5.0ms preprocess, 263.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_194316.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 (no detections), 249.0ms
# Speed: 6.0ms preprocess, 249.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_194541.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 (no detections), 243.0ms
# Speed: 3.0ms preprocess, 243.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_194551.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 (no detections), 250.0ms
# Speed: 4.0ms preprocess, 250.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_194606.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 1 handbag, 270.0ms
# Speed: 5.0ms preprocess, 270.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_194621.jpg: 1 items detected, 1 masks drawn.
#
# 0: 640x480 1 handbag, 261.0ms
# Speed: 3.0ms preprocess, 261.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Processed 20240713_194630.jpg: 1 items detected, 1 masks drawn.
# Processing screws dataset...
#
# 0: 480x640 2 birds, 2 kites, 1 clock, 380.0ms
# Speed: 5.0ms preprocess, 380.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# Processed img1.jpg: 1 items detected, 1 masks drawn.
#
# 0: 448x640 13 birds, 2 kites, 1 clock, 260.0ms
# Speed: 4.0ms preprocess, 260.0ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Processed img1_43_nosy.jpg: 1 items detected, 1 masks drawn.
#
# 0: 448x640 1 refrigerator, 252.0ms
# Speed: 4.0ms preprocess, 252.0ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Processed img1_43_nosy_output.jpg: 1 items detected, 1 masks drawn.
#
# 0: 480x640 1 refrigerator, 358.0ms
# Speed: 15.0ms preprocess, 358.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Processed img1_output.jpg: 1 items detected, 1 masks drawn.
#
# 0: 512x640 2 birds, 1 clock, 299.0ms
# Speed: 4.0ms preprocess, 299.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Processed img2.jpg: 1 items detected, 1 masks drawn.
#
# 0: 512x640 1 refrigerator, 274.0ms
# Speed: 3.0ms preprocess, 274.0ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
# Processed img2_output.jpg: 1 items detected, 1 masks drawn.
#
# 0: 384x640 19 birds, 241.0ms
# Speed: 2.0ms preprocess, 241.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed img3.jpg: 1 items detected, 1 masks drawn.
#
# 0: 384x640 1 refrigerator, 232.0ms
# Speed: 5.0ms preprocess, 232.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed img3_output.jpg: 1 items detected, 1 masks drawn.
#
# 0: 384x640 22 birds, 212.0ms
# Speed: 5.0ms preprocess, 212.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed img4.jpg: 1 items detected, 1 masks drawn.
#
# 0: 384x640 1 refrigerator, 266.0ms
# Speed: 4.0ms preprocess, 266.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed img4_output.jpg: 1 items detected, 1 masks drawn.
#
# 0: 384x640 28 birds, 231.0ms
# Speed: 3.0ms preprocess, 231.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed img5.jpg: 1 items detected, 1 masks drawn.
#
# 0: 384x640 1 refrigerator, 213.0ms
# Speed: 3.0ms preprocess, 213.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed img5_output.jpg: 1 items detected, 1 masks drawn.
#
# 0: 384x640 19 birds, 232.0ms
# Speed: 3.0ms preprocess, 232.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed img6.jpg: 1 items detected, 1 masks drawn.
#
# 0: 384x640 1 refrigerator, 174.0ms
# Speed: 4.0ms preprocess, 174.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed img6_output.jpg: 1 items detected, 1 masks drawn.
